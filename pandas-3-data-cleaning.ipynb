# %% [markdown]
# # Data Cleaning with Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Scenario
#
# As data scientists, we want to build a model to predict the sale price of a house in Seattle in 2019, based on its square footage. We know that the King County Department of Assessments has comprehensive data available on real property sales in the Seattle area. We need to prepare the data.

# %% [markdown]
# ### First, get the data!
#
# When working on a project involving data that can fit on our computer, we store it in a `data` directory.
#
# ```bash
# cd <project_directory>  # example: cd ~/flatiron_ds/pandas-3
# mkdir data
# cd data
# ```
#
# Note that `<project_directory>` in angle brackets is a _placeholder_. You should type the path to the actual location on your computer where you're working on this project. Do not literally type `<project_directory>` and _do not type the angle brackets_. You can see an example in the _comment_ to the right of the command above.
#
# Now, we'll need to download the two data files that we need. We can do this at the command line:
#
# ```bash
# wget https://aqua.kingcounty.gov/extranet/assessor/Real%20Property%20Sales.zip
# wget https://aqua.kingcounty.gov/extranet/assessor/Residential%20Building.zip
# ```
#
# *Note:* If you do not have the `wget` command yet, you can install it: `brew install wget`.
#
# Note that `%20` in a URL translates into a space. Even though you will *never put spaces in filenames*, you may need to deal with spaces that _other_ people have used in filenames.
#
# There are two ways to handle the spaces in these filenames when referencing them at the command line.
#
# #### 1. You can _escape_ the spaces by putting a backslash (`\`, remember _backslash is next to backspace_) before each one:
#
# `unzip Real\ Property\ Sales.zip`
#
# This is what happens if you tab-complete the filename in the terminal. Tab completion is your friend!
#
# #### 2. You can put the entire filename in quotes:
#
# `unzip "Real Property Sales.zip"`
#
# Try unzipping these files with the `unzip` command. The `unzip` command takes one argument, the name of the tile that you want to unzip.
#
#
# You can use tab completion (press the `tab` key after the first three letters) to fill in the names, including spaces. This will

# %%
sales_df = pd.read_csv('data/EXTR_RPSale.csv') #mixed types means there are int and str, etc. so it stores everything as string
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Seeing pink? Warnings are useful!
#
# Note the warning above: `DtypeWarning: Columns (1, 2) have mixed types.` Because we start with an index of zero, the columns that we're being warned about are actually the _second_ and _third_ columns, `sales_df['Major']` and `sales_df['Minor']`.

# %%
sales_df.head().T
# Out:
#                                                                     0  \
# ExciseTaxNbr                                                  2687551
# Major                                                          138860
# Minor                                                             110
# DocumentDate                                               08/21/2014
# SalePrice                                                      245000
# RecordingNbr                                           20140828001436
# Volume
# Page
# PlatNbr
# PlatType
# PlatLot
# PlatBlock
# SellerName          WENKLE NOEL SMITH -TRUSTEE                    ...
# BuyerName           ALEXANDER APRIL                               ...
# PropertyType                                                        3
# PrincipalUse                                                        6
# SaleInstrument                                                      3
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                          1
# PropertyClass                                                       8
# SaleWarning
#
#                                                                     1  \
# ExciseTaxNbr                                                  1235111
# Major                                                          664885
# Minor                                                              40
# DocumentDate                                               07/09/1991
# SalePrice                                                           0
# RecordingNbr                                           199203161090
# Volume                                                            071
# Page                                                              001
# PlatNbr                                                        664885
# PlatType                                                            C
# PlatLot                                                B102
# PlatBlock
# SellerName          HERRMAN JEFFREY A+PAULINE A                   ...
# BuyerName           HERRMAN PAULINE A TTEE                        ...
# PropertyType                                                        3
# PrincipalUse                                                        0
# SaleInstrument                                                     26
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                         18
# PropertyClass                                                       3
# SaleWarning                                                        11
#
#                                                                     2  \
# ExciseTaxNbr                                                  2704079
# Major                                                          423943
# Minor                                                              50
# DocumentDate                                               10/11/2014
# SalePrice                                                           0
# RecordingNbr                                           20141205000558
# Volume
# Page
# PlatNbr
# PlatType
# PlatLot
# PlatBlock
# SellerName          STEPHENS ANTHONY P                            ...
# BuyerName           STEPHENS ANTHONY P                            ...
# PropertyType                                                        3
# PrincipalUse                                                        6
# SaleInstrument                                                     15
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                         18
# PropertyClass                                                       8
# SaleWarning                                                  18 31 51
#
#                                                                     3  \
# ExciseTaxNbr                                                  2584094
# Major                                                          403700
# Minor                                                             715
# DocumentDate                                               01/04/2013
# SalePrice                                                           0
# RecordingNbr                                           20130110000910
# Volume
# Page
# PlatNbr
# PlatType
# PlatLot
# PlatBlock
# SellerName          PASTORS EDWIN                                 ...
# BuyerName           PASTORS KHRISTINA                             ...
# PropertyType                                                        3
# PrincipalUse                                                        6
# SaleInstrument                                                     15
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                         11
# PropertyClass                                                       8
# SaleWarning                                                  18 31 38
#
#                                                                     4
# ExciseTaxNbr                                                  1056831
# Major                                                          951120
# Minor                                                             900
# DocumentDate                                               04/20/1989
# SalePrice                                                       85000
# RecordingNbr                                           198904260448
# Volume                                                            117
# Page                                                              053
# PlatNbr                                                        951120
# PlatType                                                            P
# PlatLot                                                90
# PlatBlock
# SellerName          STRATHY FLORENCE G                            ...
# BuyerName           PORTER DONALD D+EVELYN V                      ...
# PropertyType                                                        3
# PrincipalUse                                                        0
# SaleInstrument                                                      2
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                          1
# PropertyClass                                                       9
# SaleWarning                                                        49

# %% [markdown]
# ### Data overload?
#
# That's a lot of columns. We're only interested in identifying the date, sale price, and square footage of each specific property. What can we do?

# %%
sales_df = sales_df[['Major', 'Minor', 'DocumentDate', 'SalePrice']]

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2014336 entries, 0 to 2014335
# Data columns (total 4 columns):
# Major           object
# Minor           object
# DocumentDate    object
# SalePrice       int64
# dtypes: int64(1), object(3)
# memory usage: 61.5+ MB

# %%
bldg_df = pd.read_csv('data/Residential Building.zip')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bldg_df
# Out:
#          Major  Minor  BldgNbr  NbrLivingUnits                        Address  \
# 0         4300    167        1               1      15223   40TH AVE S  98188
# 1         4610    399        1               1    4431   FERNCROFT RD   98040
# 2         4610    503        1               1    4516   FERNCROFT RD   98040
# 3         4610    505        1               1    4538   FERNCROFT RD   98040
# 4         4900     56        1               1      3015  SW 105TH ST   98146
# 5         4950     60        1               1     2508   VASHON CT NE  98059
# 6         5030    300        1               1     26115   201ST PL SE  98042
# 7         5030    350        1               1     20101  SE 260TH PL   98042
# 8         5100    160        1               1      2115  SW 305TH ST   98023
# 9         5200     21        1               1            1212 A  6TH AVE N
# 10        5350    300        1               1         21366  SE 289TH WAY
# 11        5350    510        1               1         21371  SE 289TH WAY
# 6               26115                           201ST
# 7               20101                       SE  260TH
# 8               2115                        SW  305TH
# 9               1212       A                    6TH
# 10              21366                       SE  289TH
# 11              21371                       SE  289TH
# 12              21561                       SE  290TH
# 13              5722                        SW  WINTHROP
# 14              5717                        SW  WINTHROP
# 15              5353                        SW  ADMIRAL
# 16              2721                            53RD
# 17              5509                        SW  CAMPBELL
# 18              5557                        SW  CAMPBELL
# 19              5344                        SW  ADMIRAL
# 20              5514                        SW  CAMPBELL
# 21              3719                        S   270TH
# 22              6521                            36TH
# 23              6546                            37TH
# 24              6506                            37TH
# 25              6502                            37TH
# 26              6506                            38TH
# 27              5952                            38TH
# 28              5937                            38TH
# 29              6026                            39TH
# ...               ...      ...             ...                        ...
# 511382          9532                            6TH
# 511383          9521                            4TH
# 511384          2143                        SW  317TH
# 511385          312                         NE  88TH
# 511386          316                         S   DIVISION
# 511387          11458                           108TH
# 511388          2324                        SE  2ND
# 511389          258                             BLAINE
# 511390          2100                        SE  2ND
# 511391          255                             BLAINE
# 511392          265                             BLAINE
# 511393          2207                        SE  2ND
# 511394          2235                        SE  3RD
# 511395          318                             EDMONDS
# 511396          265                             EDMONDS
# 511397          277                             EDMONDS
# 511398          1310                            LA FOREST
# 511399          1051                            LA FOREST
# 511400          4515                            14TH
# 511401          4536                            13TH
# 511402          4331                            14TH
# 511403          4327                            14TH
# 511404          4155                            14TH
# 511405          4158                            13TH
# 511406          4127                            13TH
# 511407          4158                            12TH
# 511408          4351                            13TH
# 511409          4314                            12TH
# 511410          4337                            12TH
# 511411          4405                            POWELL
#
#        StreetType    ...     FpMultiStory FpFreestanding  FpAdditional  \
# 0          AVE       ...                0              0             0
# 1          RD        ...                0              2             0
# 2          RD        ...                2              0             0
# 3          RD        ...                2              0             1
# 4          ST        ...                1              0             1
# 5          CT        ...                0              1             0
# 6          PL        ...                0              0             0
# 7          PL        ...                0              0             0
# 8          ST        ...                0              0             0
# 9          AVE       ...                0              0             0
# 10         WAY       ...                0              0             0
# 11         WAY       ...                0              0             0
# 12         PL        ...                0              0             0
# 13         ST        ...                1              0             2
# 14         ST        ...                1              0             1
# 15         WAY       ...                0              0             0
# 16         AVE       ...                1              0             1
# 17         PL        ...                0              0             0
# 18         PL        ...                0              1             0
# 19         WAY       ...                0              0             0
# 20         PL        ...                0              0             0
# 21         ST        ...                1              0             0
# 22         AVE       ...                1              0             1
# 23         AVE       ...                0              0             0
# 24         AVE       ...                1              0             1
# 25         AVE       ...                1              0             1
# 26         AVE       ...                1              0             0
# 27         AVE       ...                0              0             0
# 28         AVE       ...                0              0             0
# 29         AVE       ...                0              1             0
# ...           ...    ...              ...            ...           ...
# 511382     AVE       ...                0              0             0
# 511383     AVE       ...                0              0             0
# 511384     PL        ...                0              0             0
# 511385     ST        ...                0              1             0
# 511386     ST        ...                0              1             0
# 511387     AVE       ...                1              0             1
# 511388     PL        ...                0              0             0
# 511389     CT        ...                0              0             0
# 511390     PL        ...                0              0             0
# 511391     DR        ...                0              0             0
# 511392     DR        ...                0              0             0
# 14              4          0
# 15              3          0
# 16              5          0
# 17              4          0
# 18              4          0
# 19              4          0
# 20              3          0
# 21              3          0
# 22              3          0
# 23              3          0
# 24              3          0
# 25              3          0
# 26              4          0
# 27              3          0
# 28              5          0
# 29              3          0
# ...           ...        ...
# 511382          3          0
# 511383          4          0
# 511384          4          0
# 511385          3          0
# 511386          4          0
# 511387          3          0
# 511388          3       3500
# 511389          3       3500
# 511390          3       3500
# 511391          3       3500
# 511392          3       3500
# 511393          4       3500
# 511394          4       3500
# 511395          3       3500
# 511396          3       3500
# 511397          3       3500
# 511398          3      12000
# 511399          3      12000
# 511400          3          0
# 511401          3          0
# 511402          3          0
# 511403          3          0
# 511404          4          0
# 511405          3          0
# 511406          3          0
# 511407          3          0
# 511408          3          0
# 511409          5          0
# 511410          3          0
# 511411          4          0
#
# [511412 rows x 50 columns]

# %% [markdown]
# ### Another warning! Which column has index 11?

# %%
bldg_df.columns[11]
# Out:
# 'ZipCode'

# %% [markdown]
# `ZipCode` seems like a potentially useful column. We'll need it to determine which house sales took place in Seattle.

# %%
bldg_df.head().T
# Out:
#                                             0                            1  \
# Major                                    4300                         4610
# Minor                                     167                          399
# BldgNbr                                     1                            1
# NbrLivingUnits                              1                            1
# Address             15223   40TH AVE S  98188  4431   FERNCROFT RD   98040
# BuildingNumber                          15223                        4431
# Fraction
# DirectionPrefix
# StreetName          40TH                         FERNCROFT
# StreetType                             AVE                          RD
# DirectionSuffix                            S
# ZipCode                                 98188                        98040
# Stories                                     1                            2
# BldgGrade                                   6                            9
# BldgGradeVar                                0                            0
# SqFt1stFloor                              990                          980
# SqFtHalfFloor                               0                            0
# SqFt2ndFloor                                0                         1140
# SqFtUpperFloor                              0                            0
# SqFtUnfinFull                               0                            0
# SqFtUnfinHalf                               0                            0
# SqFtTotLiving                             990                         2950
# SqFtTotBasement                           990                          940
# SqFtFinBasement                             0                          830
# FinBasementGrade                            0                            9
# SqFtGarageBasement                          0                            0
# SqFtGarageAttached                          0                          480
# DaylightBasement                                                         Y
# SqFtOpenPorch                              80                            0
# SqFtEnclosedPorch                           0                            0
# SqFtDeck                                    0                          600
# HeatSystem                                  6                            5
# HeatSource                                  1                            2
# BrickStone                                  0                            0
# ViewUtilization                                                          N
# Bedrooms                                    2                            3
# BathHalfCount                               0                            1
# Bath3qtrCount                               0                            0
# BathFullCount                               1                            2
# FpSingleStory                               0                            0
# FpMultiStory                                0                            0
# FpFreestanding                              0                            2
# FpAdditional                                0                            0
# YrBuilt                                  1922                         1978
# YrRenovated                                 0                            0
# PcntComplete                                0                            0
# Obsolescence                                0                            0
# PcntNetCondition                            0                            0
# Condition                                   3                            4
# AddnlCost                                   0                            0
#
#                                               2                            3  \
# Major                                      4610                         4610
# Minor                                       503                          505
# BldgNbr                                       1                            1
# NbrLivingUnits                                1                            1
# Address             4516   FERNCROFT RD   98040  4538   FERNCROFT RD   98040
# BuildingNumber                            4516                         4538
# Fraction
# DirectionPrefix
# StreetName            FERNCROFT                    FERNCROFT
# StreetType                               RD                           RD
# DirectionSuffix
# ZipCode                                   98040                        98040
# Stories                                       2                            2
# BldgGrade                                     9                           11
# BldgGradeVar                                  0                            0
# SqFt1stFloor                               1916                         2250
# SqFtHalfFloor                                 0                            0
# SqFt2ndFloor                               1473                         1850
# SqFtUpperFloor                                0                            0
# SqFtUnfinFull                                 0                            0
# SqFtUnfinHalf                                 0                            0
# SqFtTotLiving                              3389                         4100
# SqFtTotBasement                               0                            0
# SqFtFinBasement                               0                            0
# FinBasementGrade                              0                            0
# SqFtGarageBasement                            0                            0
# SqFtGarageAttached                          552                          690
# DaylightBasement                              N                            N
# SqFtOpenPorch                               336                          120
# SqFtEnclosedPorch                           192                            0
# SqFtDeck                                   1028                          980
# HeatSystem                                    5                            5
# HeatSource                                    2                            2
# BrickStone                                    0                            0
# ViewUtilization                               N                            N
# Bedrooms                                      3                            5
# BathHalfCount                                 1                            1
# Bath3qtrCount                                 1                            0
# BathFullCount                                 1                            3
# FpSingleStory                                 0                            0
# FpMultiStory                                  2                            2
# FpFreestanding                                0                            0
# FpAdditional                                  0                            1
# YrBuilt                                    1970                         1989
# YrRenovated                                   0                            0
# PcntComplete                                  0                            0
# Obsolescence                                  0                            0
# PcntNetCondition                              0                            0
# Condition                                     4                            3
# AddnlCost                                     0                        20000
#
#                                             4
# Major                                    4900
# Minor                                      56
# BldgNbr                                     1
# NbrLivingUnits                              1
# Address             3015  SW 105TH ST   98146
# BuildingNumber                          3015
# Fraction
# DirectionPrefix                            SW
# StreetName          105TH
# StreetType                             ST
# DirectionSuffix
# ZipCode                                 98146
# Stories                                     1
# BldgGrade                                   7
# BldgGradeVar                                0
# SqFt1stFloor                             1040
# SqFtHalfFloor                               0
# SqFt2ndFloor                                0
# SqFtUpperFloor                              0
# SqFtUnfinFull                               0
# SqFtUnfinHalf                               0
# SqFtTotLiving                            1570
# SqFtTotBasement                          1040
# SqFtFinBasement                           530
# FinBasementGrade                            7
# SqFtGarageBasement                        430
# SqFtGarageAttached                          0
# DaylightBasement
# SqFtOpenPorch                               0
# SqFtEnclosedPorch                           0
# SqFtDeck                                  100
# HeatSystem                                  5
# HeatSource                                  1
# BrickStone                                  0
# ViewUtilization
# Bedrooms                                    3
# BathHalfCount                               0
# Bath3qtrCount                               0
# BathFullCount                               1
# FpSingleStory                               0
# FpMultiStory                                1
# FpFreestanding                              0
# FpAdditional                                1
# YrBuilt                                  1967
# YrRenovated                                 0
# PcntComplete                                0
# Obsolescence                                0
# PcntNetCondition                            0
# Condition                                   3
# AddnlCost                                   0

# %% [markdown]
# ### So many features!
#
# As data scientists, we should be _very_ cautious about discarding potentially useful data. But, today, we're interested in _only_ the total square footage of each property. What can we do?

# %%
bldg_df = bldg_df[['Major', 'Minor', 'SqFtTotLiving', 'ZipCode']]

# %%
bldg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511412 entries, 0 to 511411
# Data columns (total 4 columns):
# Major            511412 non-null int64
# Minor            511412 non-null int64
# SqFtTotLiving    511412 non-null int64
# ZipCode          468372 non-null object
# dtypes: int64(3), object(1)
# memory usage: 15.6+ MB

# %%
#sales_data = pd.merge(sales_df, bldg_df, on=['Major', 'Minor'])
#Major section is object on one data set and an int on the other

# %% [markdown]
# ### Error!
#
# Why are we seeing an error when we try to join the dataframes?
#
# <table>
#     <tr>
#         <td style="text-align:left"><pre>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2013160 entries, 0 to 2013159
# Data columns (total 4 columns):
# Major           object
# Minor           object
# DocumentDate    object
# SalePrice       int64
# dtypes: int64(1), object(3)
# memory usage: 61.4+ MB</pre></td>
#         <td style="text-align:left"><pre>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511359 entries, 0 to 511358
# Data columns (total 4 columns):
# Major            511359 non-null int64
# Minor            511359 non-null int64
# SqFtTotLiving    511359 non-null int64
# ZipCode          468345 non-null object
# dtypes: int64(3), object(1)
# memory usage: 15.6+ MB
# </pre></td>
#     </tr>
# </table>
#
# Review the error message in light of the above:
#
# * `ValueError: You are trying to merge on object and int64 columns.`

# %%
#sales_df['Major'] = pd.to_numeric(sales_df['Major'])

# %% [markdown]
# ### Error!
#
# Note the useful error message above:
#
# `ValueError: Unable to parse string "      " at position 936643`
#
# In this case, we want to treat non-numeric values as missing values. Let's see if there's a way to change how the `pd.to_numeric` function handles errors.

# %%
# The single question mark means "show me the docstring"
pd.to_numeric?

# %% [markdown]
# Here's the part that we're looking for:
# ```
# errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#     - If 'raise', then invalid parsing will raise an exception
#     - If 'coerce', then invalid parsing will be set as NaN
#     - If 'ignore', then invalid parsing will return the input
# ```
#
# Let's try setting the `errors` parameter to `'coerce'`.

# %%
sales_df['Major'] = pd.to_numeric(sales_df['Major'], errors='coerce')

# %% [markdown]
# Did it work?

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2014336 entries, 0 to 2014335
# Data columns (total 4 columns):
# Major           float64
# Minor           object
# DocumentDate    object
# SalePrice       int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 61.5+ MB

# %% [markdown]
# It worked! Let's do the same thing with the `Minor` parcel number.

# %%
sales_df['Minor'] = pd.to_numeric(sales_df['Minor'], errors='coerce')

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2014336 entries, 0 to 2014335
# Data columns (total 4 columns):
# Major           float64
# Minor           float64
# DocumentDate    object
# SalePrice       int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 61.5+ MB

# %% [markdown]
# Now, let's try our join again.

# %%
sales_data = pd.merge(sales_df, bldg_df, on=['Major', 'Minor'])

# %%
sales_data.head()
# Out:
#       Major  Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 0  138860.0  110.0   08/21/2014     245000           1490   98002
# 1  138860.0  110.0   06/12/1989     109300           1490   98002
# 2  138860.0  110.0   01/16/2005      14684           1490   98002
# 3  138860.0  110.0   06/08/2005          0           1490   98002
# 4  423943.0   50.0   10/11/2014          0            960   98092

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1437522 entries, 0 to 1437521
# Data columns (total 6 columns):
# Major            1437522 non-null float64
# Minor            1437522 non-null float64
# DocumentDate     1437522 non-null object
# SalePrice        1437522 non-null int64
# SqFtTotLiving    1437522 non-null int64
# ZipCode          1322148 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 76.8+ MB

# %% [markdown]
# We can see right away that we're missing zip codes for many of the sales transactions. (1321536 non-null entries for ZipCode is fewer than the 1436772 entries in the dataframe.)

# %%
sales_data.loc[sales_data['ZipCode'].isna()].head()
# Out:
#         Major  Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 99   858140.0  376.0   05/22/2012          0            900     NaN
# 100  858140.0  376.0   11/28/2017          0            900     NaN
# 152  720319.0  520.0   11/20/2013     699950           2840     NaN
# 153  720319.0  520.0   09/16/2013          0           2840     NaN
# 163  894677.0  240.0   12/21/2016     818161           2450     NaN

# %% [markdown]
# Because we are interested in finding houses in Seattle zip codes, we will need to drop the rows with missing zip codes.

# %%
sales_data = sales_data.loc[~sales_data['ZipCode'].isna(), :]
#.isna() function changes NaN to true or false; 1 or 0 

sales_data.head()
# Out:
#       Major  Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 0  138860.0  110.0   08/21/2014     245000           1490   98002
# 1  138860.0  110.0   06/12/1989     109300           1490   98002
# 2  138860.0  110.0   01/16/2005      14684           1490   98002
# 3  138860.0  110.0   06/08/2005          0           1490   98002
# 4  423943.0   50.0   10/11/2014          0            960   98092

# %% [markdown]
# # Your turn: Data Cleaning with Pandas

# %% [markdown]
# ### 1. Investigate and drop rows with invalid values in the SalePrice and SqFtTotLiving columns.
#
# Use multiple notebook cells to accomplish this! Press `[esc]` then `B` to create a new cell below the current cell. Press `[return]` to start typing in the new cell.

# %%
sales_data_i = sales_data[['SalePrice', 'SqFtTotLiving', 'DocumentDate']]
sales_data_i.head()
# Out:
#    SalePrice  SqFtTotLiving DocumentDate
# 0     245000           1490   08/21/2014
# 1     109300           1490   06/12/1989
# 2      14684           1490   01/16/2005
# 3          0           1490   06/08/2005
# 4          0            960   10/11/2014

# %%
sales_data_i=sales_data_i.loc[sales_data_i['SalePrice']!=0] #you have to set it to itself in order to overwrite
sales_data_i.head()
# Out:
#    SalePrice  SqFtTotLiving DocumentDate
# 0     245000           1490   08/21/2014
# 1     109300           1490   06/12/1989
# 2      14684           1490   01/16/2005
# 6      96000            960   07/15/1999
# 7     127500            960   01/08/2001

# %% [markdown]
# ### 2. Investigate and handle non-numeric ZipCode values
#
# Can you find a way to shorten ZIP+4 codes to the first five digits?
#
# What's the right thing to do with missing values?

# %%
# Read the error message and decide how to fix it.
# Note: using errors='coerce' is the *wrong* choice in this case.
def is_integer(x):
    try:
        _ = int(x)
    except ValueError:
        return False
    return True

sales_data.loc[sales_data['ZipCode'].apply(is_integer) == False, 'ZipCode'].str[:5].head()
# Out:
# 10168    98042
# 10169    98042
# 10170    98042
# 10171    98042
# 10172    98042
# Name: ZipCode, dtype: object

# %% [markdown]
# ### 3. Add a column for PricePerSqFt

# %%
sales_data_i.head()
# Out:
#    SalePrice  SqFtTotLiving DocumentDate
# 0     245000           1490   08/21/2014
# 1     109300           1490   06/12/1989
# 2      14684           1490   01/16/2005
# 6      96000            960   07/15/1999
# 7     127500            960   01/08/2001

# %%
PricePerSqFt = sales_data_i['SalePrice'] / sales_data_i['SqFtTotLiving']
PricePerSqFt.head()
# Out:
# 0    164.429530
# 1     73.355705
# 2      9.855034
# 6    100.000000
# 7    132.812500
# dtype: float64

# %%
sales_data_i['PricePerSqFt'] = PricePerSqFt.values

# %%
sales_data_i_2019 = sales_data_i.assign(PricePerSqFt=PricePerSqFt.values)

# %%
sales_data_i_2019.head()
# Out:
#    SalePrice  SqFtTotLiving DocumentDate  PricePerSqFt
# 0     245000           1490   2014-08-21    164.429530
# 1     109300           1490   1989-06-12     73.355705
# 2      14684           1490   2005-01-16      9.855034
# 6      96000            960   1999-07-15    100.000000
# 7     127500            960   2001-01-08    132.812500

# %%
sales_data_i.round(2).head()
# Out:
#    SalePrice  SqFtTotLiving DocumentDate  PricePerSqFt
# 0     245000           1490   08/21/2014        164.43
# 1     109300           1490   06/12/1989         73.36
# 2      14684           1490   01/16/2005          9.86
# 6      96000            960   07/15/1999        100.00
# 7     127500            960   01/08/2001        132.81

# %%
sales_data_i = sales_data_i.round(2)

# %%
sales_data_i.head()
# Out:
#    SalePrice  SqFtTotLiving DocumentDate  PricePerSqFt
# 0     245000           1490   08/21/2014        164.43
# 1     109300           1490   06/12/1989         73.36
# 2      14684           1490   01/16/2005          9.86
# 6      96000            960   07/15/1999        100.00
# 7     127500            960   01/08/2001        132.81

# %% [markdown]
# ### 4. Subset the data to 2019 sales only.
#
# We can assume that the DocumentDate is approximately the sale date.

# %%
sales_data_i[['DocumentDate']].head()
# Out:
#   DocumentDate
# 0   08/21/2014
# 1   06/12/1989
# 2   01/16/2005
# 6   07/15/1999
# 7   01/08/2001

# %%
type(sales_data_i['DocumentDate'])
# Out:
# pandas.core.series.Series

# %%
sales_data_i.head()
# Out:
#    SalePrice  SqFtTotLiving DocumentDate  PricePerSqFt
# 0     245000           1490   08/21/2014        164.43
# 1     109300           1490   06/12/1989         73.36
# 2      14684           1490   01/16/2005          9.86
# 6      96000            960   07/15/1999        100.00
# 7     127500            960   01/08/2001        132.81

# %%
sales_date = sales_data['DocumentDate']
sales_date.head()
# Out:
# 0    08/21/2014
# 1    06/12/1989
# 2    01/16/2005
# 3    06/08/2005
# 4    10/11/2014
# Name: DocumentDate, dtype: object

# %%
sales_data_i_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 867416 entries, 0 to 1437520
# Data columns (total 4 columns):
# SalePrice        867416 non-null int64
# SqFtTotLiving    867416 non-null int64
# DocumentDate     867416 non-null datetime64[ns]
# PricePerSqFt     867416 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 33.1 MB

# %%
sales_data_i_2019['DocumentDate'] = pd.to_datetime(sales_data_i['DocumentDate'])
#to_datetime converts an object to a date format

# %%
#sales_data[sales_date.to_datetime.year == 2019]
sales_data_i_2019=sales_data_i_2019[sales_data_i_2019["DocumentDate"].dt.year == 2019]
sales_data_i_2019.head()
# Out:
#       SalePrice  SqFtTotLiving DocumentDate  PricePerSqFt
# 605      390000           1780   2019-03-06    219.101124
# 651      923000           2550   2019-03-13    361.960784
# 868      935000           2460   2019-02-06    380.081301
# 1063     890000           2380   2019-02-15    373.949580
# 1341     380000           1750   2019-03-04    217.142857

# %% [markdown]
# ### 5. Subset the data to zip codes within the City of Seattle.
#
# You'll need to find a list of Seattle zip codes!

# %%
sales_data_i_2019=sales_data_i_2019.loc[sales_data_i_2019['SalePrice']!=0]

# %%
sales_data_i_2019 .head()
# Out:
#         Major   Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 441  661000.0  1020.0   2002-02-01      80694           1660   98103
# 443  661000.0  1020.0   1994-05-04     185000           1660   98103
# 579  503530.0   206.0   1993-08-25     185000           1350   98199
# 582  503530.0   206.0   2007-10-11     625000           1350   98199
# 778  890100.0  1043.0   1996-04-16     149000           1750   98125

# %%
seattle_zipcodes = [98101, 98102, 98103, 98104, 98105, 98106, 98107, 98108, 98109, 98112, 98115, 98116, 98117, 98118, 98119, 98121, 98122, 98125, 98126, 98133, 98134, 98136, 98144, 98146, 98154, 98164, 98174, 98177, 98178, 98195, 98199]

# %%
seattle_zipcodes = list(seattle_zipcodes)
seattle_zipcodes
# Out:
# [98101,
#  98102,
#  98103,
#  98104,
#  98105,
#  98106,
#  98107,
#  98108,
#  98109,
#  98112,
#  98115,
#  98116,
#  98117,
#  98118,
#  98119,
#  98121,
#  98122,
#  98125,
#  98126,
#  98133,
#  98134,
#  98136,
#  98144,
#  98146,
#  98154,
#  98164,
#  98174,
#  98177,
#  98178,
#  98195,
#  98199]

# %%
def in_seattle(x):
    seattle_zipcodes
    return x in seattle_zipcodes
sales_data_i_2019 = sales_data_i_2019.loc[sales_data_i_2019['ZipCode'].apply(in_seattle) == True, :]

# %%
sales_data_i_2019.head()
# Out:
#       SalePrice  SqFtTotLiving DocumentDate  PricePerSqFt
# 605      390000           1780   2019-03-06    219.101124
# 651      923000           2550   2019-03-13    361.960784
# 868      935000           2460   2019-02-06    380.081301
# 1063     890000           2380   2019-02-15    373.949580
# 1341     380000           1750   2019-03-04    217.142857

# %% [markdown]
# ### 6. What is the mean price per square foot for a house sold in Seattle in 2019?
#
# Don't just type the answer. Type code that generates the answer as output!

# %%
sales_data_i_2019['PricePerSqFt'].mean()
# Out:
# 401.4669645065364
